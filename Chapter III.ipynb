# %% [markdown]
# # MongoDB
#
# MongoDB is a cross-platform document-oriented database program. Classified as a NoSQL database program. Each database in MongoDB contains collections. A collection is an organized store of documents. A document is a way to organize data as a set of key-value pairs.
#
# MongoDB uses JSON-like documents (BSON) with optional schemas. MongoDB is developed by MongoDB Inc. and licensed under the Server Side Public License (SSPL).
#
# Why do we do a focus on MongoDB in this course ?
#
# https://db-engines.com/en/ranking
# https://trends.google.com/trends/?geo=US
#
#
# MongoDB is a document-oriented DB, i.e it is designed to retrieve and manage document-oriented information, also known as semi-structured data.
#
# MongoDB and the CAP theorem [1](https://stackoverflow.com/questions/11292215/where-does-mongodb-stand-in-the-cap-theorem)
#
#
# Structure:
# - [MongoDB first steps](#First_steps)
# - [CRUD operations](#CRUD)
# - [Speed up query in MongoDB and the use of Index.](#Index)
# - [Copy/Merge/Dump collections in MongoDB](#Copy)
# - [MongoDB store specific kind of data](#Specific)
# - [Bulk operations](#Bulk)
# - [Timeout issues](#Timeout)
# - [Security with MongoDB](#Security)
# - [MongoDB Atlas](#Atlas)
# - [Exercises](#Exercises)
# <a name="First_steps"></a>
# ## MongoDB first steps.
#
# At this point you should have MongoDB and MongoDB compass installed (check the readme).
# launch your MongoDB server. Check that everything works. On the cmd line (or terminal) run
#
# ```
# pip install pymongo
# ```
#
# and open your Python IDE.

# %%
import pymongo

# open connection at port 27017 https://en.wikipedia.org/wiki/List_of_TCP_and_UDP_port_numbers
client = pymongo.MongoClient('localhost', 27017)
# create db tutorial
mydb = client["tutorial"]
# create collection example
collection = mydb["example"]

#Il faut insérer au minimum un document pour que la collection apparaisse dans MongoDB

# %%
# random dict
post = {"authors" : ["Auteur1","Auteur2","Auteur3"],
         "title" : "This is paper 1",
         "affiliations" : ["University of Mannheim","University of Strasbourg","University of wonders"],
         "ref" : ["This is ref 1","This is ref 2","This is ref 3"]}
# Inserting this single dict in mongodb
collection.insert_one(post)

# %%
# same operation as before but with another dict

post = {"authors" : ["Auteur1"],
         "title" : "This is paper 2",
         "affiliations" : ["University of Turing"],
         "ref" : ["This is ref 1","This is ref 2"]}

collection.insert_one(post)

# %% [markdown]
# <a name="CRUD"></a>
# ## CRUD Operation
#
# What we have done right now is called a Create operation.
# In computer programming, create, read (aka retrieve), update, and delete (CRUD) are the four basic functions of persistent storage.

# %% [markdown]
# ### CREATE

# %%
# CREATE but not with insert_one, insert_many inserts multiple dicts that are contained by a list
# insert_many faster that insert_one (avoiding overhead of the commit).

import datetime
import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["example"]

# new_posts = list of dicts [{},{}]
new_posts = [{"author": "Mike",
              "title":"Python is fun",
               "text": "Another post!",
               "tags": ["bulk", "insert"],
              # date object format (year,month,day,hour,minute)
               "date": datetime.datetime(2009, 11, 12, 11, 14)},
              {"author": "Eliot",
               "title": "MongoDB is fun",
               "text": "and pretty easy too!",
               "date": datetime.datetime(2009, 11, 10, 10, 45)}]

collection.insert_many(new_posts)

# %%
import tqdm
import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["example"]

# in each it insert the dict {"x":1}
for i in tqdm.tqdm(range(3)):
    post = {"x":1}
    collection.insert_one(post)

# %% [markdown]
# ### READ

# %%
# READ

# get list of collections
print(mydb.list_collection_names())

# get a document
doc = collection.find_one() #renvoie le doc le plus ancien
print(doc)

# get a specific document

doc = collection.find_one({"title": "This is paper 2"})
print(doc)
# Out:
# ['example']
# {'_id': ObjectId('6429c5f2eeecb198ec66314d'), 'authors': ['Auteur1', 'Auteur2', 'Auteur3'], 'title': 'This is paper 1', 'affiliations': ['University of Mannheim', 'University of Strasbourg', 'University of wonders'], 'ref': ['This is ref 1', 'This is ref 2', 'This is ref 3']}
# {'_id': ObjectId('6429c660eeecb198ec66314e'), 'authors': ['Auteur1'], 'title': 'This is paper 2', 'affiliations': ['University of Turing'], 'ref': ['This is ref 1', 'This is ref 2']}

# %%
# get all docs
docs = collection.find() #doc est un curseur (générateur)
print(docs)
for doc in docs:
    print(doc)
# Out:
# <pymongo.cursor.Cursor object at 0x00000220F5243CD0>
# {'_id': ObjectId('6429c5f2eeecb198ec66314d'), 'authors': ['Auteur1', 'Auteur2', 'Auteur3'], 'title': 'This is paper 1', 'affiliations': ['University of Mannheim', 'University of Strasbourg', 'University of wonders'], 'ref': ['This is ref 1', 'This is ref 2', 'This is ref 3']}
# {'_id': ObjectId('6429c660eeecb198ec66314e'), 'authors': ['Auteur1'], 'title': 'This is paper 2', 'affiliations': ['University of Turing'], 'ref': ['This is ref 1', 'This is ref 2']}
# {'_id': ObjectId('6429c77ceeecb198ec663150'), 'author': 'Mike', 'title': 'Python is fun', 'text': 'Another post!', 'tags': ['bulk', 'insert'], 'date': datetime.datetime(2009, 11, 12, 11, 14)}
# {'_id': ObjectId('6429c77ceeecb198ec663151'), 'author': 'Eliot', 'title': 'MongoDB is fun', 'text': 'and pretty easy too!', 'date': datetime.datetime(2009, 11, 10, 10, 45)}
# {'_id': ObjectId('6429c7dceeecb198ec663153'), 'x': 1}
# {'_id': ObjectId('6429c7dceeecb198ec663154'), 'x': 1}
# {'_id': ObjectId('6429c7dceeecb198ec663155'), 'x': 1}

# %% [markdown]
# Notice that the query returns a generator. In other words you can load heavy DBs since you won't have in RAM the whole thing.

# %% [markdown]
# ### UPDATE

# %%
# UPDATE: 3 methods update_one(), update_many(), find_one_and_update()
# multiple modifiers: https://docs.mongodb.com/manual/reference/operator/update-field/
# upsert = True if no doc find add this one
collection.update_one({"author": "Mike"},
                      {'$set': {
                          'author': "not_mike"
                          }
                      }, upsert=False)

# %%
# Update every doc where "x" = 1, increment the value by 3
collection.update_many({'x': 1}, {'$inc': {'x': 3}})

# %%
# find one document where "author" = not_mike and set the "done" field as "Mike"
doc = collection.find_one_and_update({'author': "not_mike"}, {'$set': {'done': "Mike"}})
print(doc)

#why isn't the "done" field printed here?
# Out:
# {'_id': ObjectId('6429c77ceeecb198ec663150'), 'author': 'not_mike', 'title': 'Python is fun', 'text': 'Another post!', 'tags': ['bulk', 'insert'], 'date': datetime.datetime(2009, 11, 12, 11, 14)}

# %% [markdown]
# ### DELETE

# %%
# Delete statement

# print number of document with the key x = 4
print("init count: ", collection.count_documents({'x': 4}))
# Delete one
collection.delete_one({'x': 4})
# print number of document with the key x = 4 -1 document compared to the init query
print("after delete one: ", collection.count_documents({'x': 4}))
# Out:
# init count:  3
# after delete one:  2

# %%
# Delete all
collection.delete_many({'x': 4})
print("after delete many: ", collection.count_documents({'x': 4}))
# Out:
# after delete many:  0

# %% [markdown]
# As always I did not go through everything. You will learn more during TODOs but you can use the [documentation](https://docs.mongodb.com/manual/crud/) of MongoDB (Warning its meant for the mongodb terminal not pymongo, but it gives you an idea of what can be done, it's up to you to search how to do it on pymongo). Let's do a real example with everything we have seen. We will use arXiv api. We will work more on api next year so don't worry if you don't understand everything (again not in exam) but here's a short intro. The codes for oaipmh and api are also available on [github](https://github.com/Kwirtz/arxiv_api2mongodb)

# %%
import requests
import re
from collections import defaultdict
from lxml import etree
import tqdm
import time

# https://info.arxiv.org/help/oa/index.html to get all ids of papers in a set

# Function taken from the package sickle
def xml_to_dict(tree, paths=None, nsmap=None, strip_ns=False):
    """Convert an XML tree to a dictionary.
    :param tree: etree Element
    :type tree: :class:`lxml.etree._Element`
    :param paths: An optional list of XPath expressions applied on the XML tree.
    :type paths: list[basestring]
    :param nsmap: An optional prefix-namespace mapping for conciser spec of paths.
    :type nsmap: dict
    :param strip_ns: Flag for whether to remove the namespaces from the tags.
    :type strip_ns: bool
    """
    # if xpath empty take every path (.//)
    paths = paths or ['.//']
    nsmap = nsmap or {}
    # defaultdict = never return a keyerror but an empty list
    fields = defaultdict(list)
    for path in paths:
        elements = tree.findall(path, nsmap)
        for element in elements:
            tag = re.sub(
                r'\{.*\}', '', element.tag) if strip_ns else element.tag
            fields[tag].append(element.text)
    return dict(fields)

# List of sets from arxiv
sets = ["cs"] #correspond à Computer Science
# Parser that can be used as argument in different module. remove_blank_text to deal with newline/tab
# recover in case of broken xml, resolve_entities = True returns text directly
XMLParser = etree.XMLParser(remove_blank_text=True, recover=True, resolve_entities=False)

for set_ in tqdm.tqdm(sets):
    # requests oaipmh from arxiv with set
    response = requests.get("http://export.arxiv.org/oai2?verb=ListIdentifiers&set={}&metadataPrefix=oai_dc".format(set_))
    # init the lxml object using the parser
    tree = etree.XML(response.content, parser=XMLParser)
    # Transform the xml in dict
    papers = xml_to_dict(tree=tree)
    # get ids of every element in dict. key = {http://www.openarchives.org/OAI/2.0/}identifier
    ids = [id_.split(":")[-1] for id_ in papers["{http://www.openarchives.org/OAI/2.0/}identifier"]] #[-1] -> récupère le dernier élément
    # Write ids in txt file using list comprehension
    arxiv_txt = open('data/Chap3/arxiv_cs.txt', 'a')
    [arxiv_txt.write(id_ + "\n") for id_ in ids]
    arxiv_txt.close()
    token = papers["{http://www.openarchives.org/OAI/2.0/}resumptionToken"][0]
    time.sleep(20)
    # for sets where more than one iteration is needed (e.g you find a resumptionToken) do a while loop until no token
    done = False
    while done == False:
            response = requests.get("http://export.arxiv.org/oai2?verb=ListIdentifiers&resumptionToken={}".format(token))
            tree = etree.XML(response.content, parser=XMLParser)
            papers = xml_to_dict(tree=tree)
            ids = [id_.split(":")[-1] for id_ in papers["{http://www.openarchives.org/OAI/2.0/}identifier"]]
            if len(ids) != 10000:
                done = True
            arxiv_txt = open('data/Chap3/arxiv_cs.txt', 'a')
            [arxiv_txt.write(id_ + "\n") for id_ in ids]
            arxiv_txt.close()
            token = papers["{http://www.openarchives.org/OAI/2.0/}resumptionToken"][0]
            time.sleep(20)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import requests
import feedparser
import tqdm
import time
import pymongo

# For each id get all the metadata https://info.arxiv.org/help/api/basics.html#python_simple_example

client = pymongo.MongoClient('localhost',27017)
mydb = client["tutorial"]
collection = mydb["arxiv_api"]

# get list of ids previously downloaded
with open("data/Chap3/arxiv_cs.txt","r") as lines:
    ids = list(set(lines.read().split("\n")[0:-2]))

#init list of ids and iteration
ids_query = []

# loop through ids
for id_ in tqdm.tqdm(ids):
    #append id to list
    ids_query.append(id_)
    # if len list = 100 
    if len(ids_query) == 100 :
        # collapse list of id
        ids_query = ",".join(ids_query)
        # query the api for the 100 ids
        response = requests.get('http://export.arxiv.org/api/query?id_list={}&max_results=100'.format(ids_query))
        # parse response
        feed = feedparser.parse(response.content)
        # commit the 100 papers found
        list_of_insertion = []
        for entry in feed.entries:
            list_of_insertion.append(dict(entry))
        collection.insert_many(list_of_insertion)
        ids_query = []
        time.sleep(1/3)
# Out:
#   8%|▊         | 32199/416556 [09:29<1:53:24, 56.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4680\2933465673.py in <module>
#      25         ids_query = ",".join(ids_query)
#      26         # query the api for the 100 ids
# ---> 27         response = requests.get('http://export.arxiv.org/api/query?id_list={}&max_results=100'.format(ids_query))
#      28         # parse response
#      29         feed = feedparser.parse(response.content)
#
# c:\Users\kevin\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\Users\kevin\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\Users\kevin\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# c:\Users\kevin\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# c:\Users\kevin\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# c:\Users\kevin\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# c:\Users\kevin\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\Users\kevin\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\kevin\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# c:\Users\kevin\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# c:\Users\kevin\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# c:\Users\kevin\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# c:\Users\kevin\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Time to do some exercise ! TODOs 1-7

# %% [markdown]
# <a name="Index"></a>
# ## Speed up query in MongoDB and the use of Index.

# %% [markdown]
# If no id is specified mongo creates automatically an ObjectId for each inserted item.
# The 12-byte ObjectId value consists of:
# - a 4-byte timestamp value, representing the ObjectId’s creation, measured in seconds since the Unix epoch
# - a 5-byte random value
# - a 3-byte incrementing counter, initialized to a random value
#
# You can also create your own index. Why would you do that ? Speeds up query.

# %%
import tqdm
import pymongo

client = pymongo.MongoClient('localhost',27017)
mydb = client["tutorial"]
collection = mydb["benchmark"]

# Note that if you use insert_one, this operation will take more than an hour
# init list of insertion for insert_many

list_of_insertion = []
for i in tqdm.tqdm(range(10000000)):
    post = {"user_id":i,
           "user_name":"John"}
    list_of_insertion.append(post)
    #if iteration divisible by 15k then insert the list and reset the list
    if i % 15000 == 0:
        collection.insert_many(list_of_insertion)
        list_of_insertion = [] #Pour ne pas insérer 2 fois la même chose
        
collection.insert_many(list_of_insertion) #Au cas où il reste des choses à insérer
# Out:
# 100%|██████████| 10000000/10000000 [02:42<00:00, 61552.04it/s]

# %%
#explain()['executionStats'] information about the query, might be usefull if you are interested in why it takes time
collection.find( { "user_id": 7000000 } ).explain()['executionStats'] #La fonction explain est propre à MongoDB
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 6902,
#  'totalKeysExamined': 0,
#  'totalDocsExamined': 10000000,
#  'executionStages': {'stage': 'COLLSCAN',
#   'filter': {'user_id': {'$eq': 7000000}},
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 320,
#   'works': 10000002,
#   'advanced': 1,
#   'needTime': 10000000,
#   'needYield': 0,
#   'saveState': 10000,
#   'restoreState': 10000,
#   'isEOF': 1,
#   'direction': 'forward',
#   'docsExamined': 10000000},
#  'allPlansExecution': []}

# %%
# create index syntax = list of tuples, tuple =("name of key which will be indexed",order 1 = ascending)
collection.create_index([ ("user_id",1) ]) #1 veut dire que l'index est croissant
# Out:
# 'user_id_1'

# %%
collection.find( { "user_id": 7000000 } ).explain()['executionStats']
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 7,
#  'totalKeysExamined': 1,
#  'totalDocsExamined': 1,
#  'executionStages': {'stage': 'FETCH',
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 0,
#   'works': 2,
#   'advanced': 1,
#   'needTime': 0,
#   'needYield': 0,
#   'saveState': 0,
#   'restoreState': 0,
#   'isEOF': 1,
#   'docsExamined': 1,
#   'alreadyHasObj': 0,
#   'inputStage': {'stage': 'IXSCAN',
#    'nReturned': 1,
#    'executionTimeMillisEstimate': 0,
#    'works': 2,
#    'advanced': 1,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'keyPattern': {'user_id': 1},
#    'indexName': 'user_id_1',
#    'isMultiKey': False,
#    'multiKeyPaths': {'user_id': []},
#    'isUnique': False,
#    'isSparse': False,
#    'isPartial': False,
#    'indexVersion': 2,
#    'direction': 'forward',
#    'indexBounds': {'user_id': ['[7000000, 7000000]']},
#    'keysExamined': 1,
#    'seeks': 1,
#    'dupsTested': 0,
#    'dupsDropped': 0}},
#  'allPlansExecution': []}

# %% [markdown]
# Although creating an index speeds up some operations, don't use it everywhere.
# Creating an index works well on fields that have unique values. Using index everywhere is detrimental and eats up your RAM

# %%
# Gives you the number of bytes of the index *(10**-9) bytes to GB
print(mydb.command('collStats', 'benchmark')["totalIndexSize"]*(10**-9))
# Out:
# 0.21809152

# %% [markdown]
# What does creating an index exactly do ? Creates a new column with ordered index. Indexes improve the speed of search operations in database because instead of searching the whole document, the search is performed on the indexes that holds only few fields.
# Look up the documentation to learn more about index and some things to speed up queries
# https://docs.mongodb.com/manual/tutorial/optimize-query-performance-with-indexes-and-projections/

# %% [markdown]
# <a name="Copy"></a>
# ## Copy/Merge/Dump collections in MongoDB
#
# Imagine you want to put a collection from one DB to another, one possibility is to read from one DB and write to another.

# %%
import datetime
import pymongo

client = pymongo.MongoClient('localhost',27017)

# Create a new db that will be dumped in tutorial
mydb_old = client["tutorial_2"]
collection_old = mydb_old["example_to_dump"]

# random information, imagine it's metadata to a blogpost
new_posts = [{"author": "Augustin",
              "title":"This is a paper from another DB",
               "text": "Another post!",
               "affiliation": "University of Strasbourg",
               "date": datetime.datetime(2009, 11, 12, 11, 14)},
              {"author": "Cournot",
               "title": "This is also another paper from another DB",
               "text": "and pretty easy too!",
               "date": datetime.datetime(2009, 11, 10, 10, 45)}]

collection_old.insert_many(new_posts)

# %%
import pymongo

client = pymongo.MongoClient('localhost',27017)
mydb = client["tutorial"] 

#just iterate through every docs and insert it in a new collection in the og db.
docs = collection_old.find()
for doc in docs:
    mydb[collection_old.name].insert_one(doc)

# %% [markdown]
# You could do the same using the mongo shell (see there https://stackoverflow.com/questions/11554762/how-to-copy-a-collection-from-one-database-to-another-in-mongodb)

# %% [markdown]
# Even more useful is the merge of collections. We have 2 collections that we want to merge (i.e benchmark, benchmark_2).

# %%
# Create benchmark 2

import tqdm

collection = mydb["benchmark_2"]

# Note that if you use insert_one, this operation will take more than an hour
list_of_insertion = []

# range of 1 to 100k but increment by 2 instead of 1
for i in tqdm.tqdm(range(1,100000,2)):
    post = {"user_id":i,
           "random_value":i*100}
    list_of_insertion.append(post)
    if i % 15000 == 0:
        collection.insert_many(list_of_insertion)
        list_of_insertion = []
collection.insert_many(list_of_insertion)
# Out:
# 100%|██████████| 50000/50000 [00:00<00:00, 964088.14it/s]

# %%
import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["benchmark"]

# lookup/unwind/project are a type of aggregation pipeline, Documents pass through the stages of a pipeline in sequence.
# Initial collection in collection.aggregate. lookup in the collection "from", match on localfield (init_collection)
# and foreignfield (from_collection). call the key-value of the from_collection as "cellmodels" results = 
#{"cellmodels":[{key-value}:{key-value}]}
# unwind cellmodels = expand array
# project = select fields

pipeline = [{'$lookup': 
                {'from' : 'benchmark_2',
                 'localField' : 'user_id',
                 'foreignField' : 'user_id',
                 'as' : 'cellmodels'}}, #infos du benchmark_2
            {'$unwind': '$cellmodels'},  #sort les éléments d'une liste
            {'$project': 
                {'user_id':1,"user_name":1, 'cellmodels.user_id':1, 'cellmodels.random_value':1}} 
             ]

documents = collection.aggregate(pipeline) #C'est ici que le join est ordonné
for i in range(20):
    print(next(documents))

#Plus complexe que sur SQL, mais on ne devrait pas avoir besoin de join si souvent qu'en SQL.
# Out:
# {'_id': ObjectId('642a8eddf77712f78a184596'), 'user_id': 1, 'user_name': 'John', 'cellmodels': {'user_id': 1, 'random_value': 100}}
# {'_id': ObjectId('642a8eddf77712f78a184598'), 'user_id': 3, 'user_name': 'John', 'cellmodels': {'user_id': 3, 'random_value': 300}}
# {'_id': ObjectId('642a8eddf77712f78a18459a'), 'user_id': 5, 'user_name': 'John', 'cellmodels': {'user_id': 5, 'random_value': 500}}
# {'_id': ObjectId('642a8eddf77712f78a18459c'), 'user_id': 7, 'user_name': 'John', 'cellmodels': {'user_id': 7, 'random_value': 700}}
# {'_id': ObjectId('642a8eddf77712f78a18459e'), 'user_id': 9, 'user_name': 'John', 'cellmodels': {'user_id': 9, 'random_value': 900}}
# {'_id': ObjectId('642a8eddf77712f78a1845a0'), 'user_id': 11, 'user_name': 'John', 'cellmodels': {'user_id': 11, 'random_value': 1100}}
# {'_id': ObjectId('642a8eddf77712f78a1845a2'), 'user_id': 13, 'user_name': 'John', 'cellmodels': {'user_id': 13, 'random_value': 1300}}
# {'_id': ObjectId('642a8eddf77712f78a1845a4'), 'user_id': 15, 'user_name': 'John', 'cellmodels': {'user_id': 15, 'random_value': 1500}}
# {'_id': ObjectId('642a8eddf77712f78a1845a6'), 'user_id': 17, 'user_name': 'John', 'cellmodels': {'user_id': 17, 'random_value': 1700}}
# {'_id': ObjectId('642a8eddf77712f78a1845a8'), 'user_id': 19, 'user_name': 'John', 'cellmodels': {'user_id': 19, 'random_value': 1900}}
# {'_id': ObjectId('642a8eddf77712f78a1845aa'), 'user_id': 21, 'user_name': 'John', 'cellmodels': {'user_id': 21, 'random_value': 2100}}
# {'_id': ObjectId('642a8eddf77712f78a1845ac'), 'user_id': 23, 'user_name': 'John', 'cellmodels': {'user_id': 23, 'random_value': 2300}}
# {'_id': ObjectId('642a8eddf77712f78a1845ae'), 'user_id': 25, 'user_name': 'John', 'cellmodels': {'user_id': 25, 'random_value': 2500}}
# {'_id': ObjectId('642a8eddf77712f78a1845b0'), 'user_id': 27, 'user_name': 'John', 'cellmodels': {'user_id': 27, 'random_value': 2700}}
# {'_id': ObjectId('642a8eddf77712f78a1845b2'), 'user_id': 29, 'user_name': 'John', 'cellmodels': {'user_id': 29, 'random_value': 2900}}
# {'_id': ObjectId('642a8eddf77712f78a1845b4'), 'user_id': 31, 'user_name': 'John', 'cellmodels': {'user_id': 31, 'random_value': 3100}}
# {'_id': ObjectId('642a8eddf77712f78a1845b6'), 'user_id': 33, 'user_name': 'John', 'cellmodels': {'user_id': 33, 'random_value': 3300}}
# {'_id': ObjectId('642a8eddf77712f78a1845b8'), 'user_id': 35, 'user_name': 'John', 'cellmodels': {'user_id': 35, 'random_value': 3500}}
# {'_id': ObjectId('642a8eddf77712f78a1845ba'), 'user_id': 37, 'user_name': 'John', 'cellmodels': {'user_id': 37, 'random_value': 3700}}
# {'_id': ObjectId('642a8eddf77712f78a1845bc'), 'user_id': 39, 'user_name': 'John', 'cellmodels': {'user_id': 39, 'random_value': 3900}}

# %% [markdown]
# The different [merges](https://www.dofactory.com/sql/join):
#
# ![sql](./img/sql-joins.png "sql-joins")

# %% [markdown]
# lookup is part of a bigger feature of MongoDB called "Aggregation". CRUD operations should be enough most of the times especially when used with python. For example for the merge seen before you could do it multiple ways but, to the best of my knowledge, lookup is the most efficient.
#
# I recommend you to read more about this Aggregation process but it's outside of the scope of this lecture. (Maybe more exercises at the end of the course ? merge, match and so on)

# %% [markdown]
# Now you know the basic operations on MongoDB. To read more on queries and other stuff: https://docs.mongodb.com/manual/.

# %%
# get a sample

import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["benchmark"]

docs = collection.aggregate([{ "$sample": { "size": 10000 } }])

print(len(list(docs)))
# Out:
# 10000

# %% [markdown]
# # TODO time 8-10

# %% [markdown]
# <a name="Specific"></a>
# ## MongoDB store specific kind of data.
#
# We will finish the Chapter II by discussing a neat trick to store different data type in MongoDB.
# Imagine you are working on pictures, more specifically you try to scrap website and sometimes you get images you want to store. You'd like to use MongoDB to centralize the data in one DB. How would one do it ?

# %%
# We are using the PIL library to load the image but you can also use other libraries like opencv
from PIL import Image
# Using matplotlib to show the image
from matplotlib import pyplot
image = Image.open('data/Chap3/FSEG.jpg')
pyplot.imshow(image)
pyplot.show()

# %%
# Now that the image is loaded we need to convert it to a numpy array
import numpy as np
from bson.binary import Binary
import pickle
import pymongo

# img to np array
data = np.asarray(image)
# Check the shape
print(data.shape)
#init dict
post = {}
# pickle dump the numpy array and then binarize it (reminder MongoDB = Bson = Bytes json)
post['image'] = Binary( pickle.dumps( data, protocol=2) ) 

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["image"]
collection.insert_one(post)
# Out:
# (212, 847, 3)

# %%
# Load it back
import pymongo
import pickle
from PIL import Image
from matplotlib import pyplot

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["image"]
docs = collection.find()
# load the binary object
doc =  pickle.loads(next(docs)["image"])
print(doc.shape,type(doc))
# From numpy to img
image = Image.fromarray(doc)
# Show image
pyplot.imshow(image)
pyplot.show()
# Out:
# (212, 847, 3) <class 'numpy.ndarray'>

# %% [markdown]
# <a name="Bulk"></a>
# ## Bulk operations
#
# Updating/Writing in a for loop is fine (one request per write). However if you need to optimize your process you can do multiple operations in a single request. This is called bulk write/update operations. There's two types of bulk operation "ordered" and "unordered". Unordered can be parallelized hence faster than ordered. let's continue to build on the benchmark collection.

# %%
import tqdm
import names
import pymongo


client = pymongo.MongoClient('localhost',27017)
mydb = client["tutorial"]
collection = mydb["benchmark"]

docs = collection.find({}, no_cursor_timeout=True).limit(100000)
    
list_of_insertion = []
for doc in tqdm.tqdm(docs):
    list_of_insertion.append(pymongo.UpdateOne({"user_id": doc["user_id"]},
                                               {'$set': {"user_name": names.get_full_name()}},
                                               upsert = True))

collection.bulk_write(list_of_insertion)
# Out:
# c:\Users\kevin\anaconda3\lib\site-packages\pymongo\collection.py:1650: UserWarning: use an explicit session with no_cursor_timeout=True otherwise the cursor may still timeout after 30 minutes, for more info see https://mongodb.com/docs/v4.4/reference/method/cursor.noCursorTimeout/#session-idle-timeout-overrides-nocursortimeout
#   return Cursor(self, *args, **kwargs)
# 7286it [00:22, 329.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4680\2173738514.py in <module>
#      13 for doc in tqdm.tqdm(docs):
#      14     list_of_insertion.append(pymongo.UpdateOne({"user_id": doc["user_id"]},
# ---> 15                                                {'$set': {"user_name": names.get_full_name()}},
#      16                                                upsert = True))
#      17
#
# c:\Users\kevin\anaconda3\lib\site-packages\names\__init__.py in get_full_name(gender)
#      41
#      42 def get_full_name(gender=None):
# ---> 43     return "{0} {1}".format(get_first_name(gender), get_last_name())
#
# c:\Users\kevin\anaconda3\lib\site-packages\names\__init__.py in get_last_name()
#      37
#      38 def get_last_name():
# ---> 39     return get_name(FILES['last']).capitalize()
#      40
#      41
#
# c:\Users\kevin\anaconda3\lib\site-packages\names\__init__.py in get_name(filename)
#      23     selected = random.random() * 90
#      24     with open(filename) as name_file:
# ---> 25         for line in name_file:
#      26             name, _, cummulative, _ = line.split()
#      27             if float(cummulative) > selected:
#
# c:\Users\kevin\anaconda3\lib\codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %% [markdown]
# <a name="Timeout"></a>
# ## Timeout issues.
#
# MongoDB cursor can timeout at some point, this is because it either took too long to respond to the query or your operation in betweens calls take too much time. the default cursor timeout for mongodb is 10 minutes, you can use the argument "no_cursor_timeout=True" which extends the timeout limit to 30 minutes. The other option is to create a session and refresh it automatically.

# %%
import tqdm
import names
import pymongo

client = pymongo.MongoClient('localhost',27017)
mydb = client["tutorial"]
collection = mydb["benchmark"]

session = client.start_session()

docs = collection.find({}, no_cursor_timeout = True, session = session).limit(100000)
    
list_of_insertion = []
for doc in tqdm.tqdm(docs):
    list_of_insertion.append(pymongo.UpdateOne({"user_id": doc["user_id"]},
                                               {'$set': {"user_name": names.get_full_name()}},
                                               upsert = True))
    if len(list_of_insertion) % 1000 == 0:
        client.admin.command('refreshSessions', [session.session_id], session=session)

collection_output.bulk_write(list_of_insertion)
# Out:
# 6343it [00:20, 310.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4680\2674033667.py in <module>
#      14 for doc in tqdm.tqdm(docs):
#      15     list_of_insertion.append(pymongo.UpdateOne({"user_id": doc["user_id"]},
# ---> 16                                                {'$set': {"user_name": names.get_full_name()}},
#      17                                                upsert = True))
#      18     if len(list_of_insertion) % 1000 == 0:
#
# c:\Users\kevin\anaconda3\lib\site-packages\names\__init__.py in get_full_name(gender)
#      41
#      42 def get_full_name(gender=None):
# ---> 43     return "{0} {1}".format(get_first_name(gender), get_last_name())
#
# c:\Users\kevin\anaconda3\lib\site-packages\names\__init__.py in get_last_name()
#      37
#      38 def get_last_name():
# ---> 39     return get_name(FILES['last']).capitalize()
#      40
#      41
#
# c:\Users\kevin\anaconda3\lib\site-packages\names\__init__.py in get_name(filename)
#      23     selected = random.random() * 90
#      24     with open(filename) as name_file:
# ---> 25         for line in name_file:
#      26             name, _, cummulative, _ = line.split()
#      27             if float(cummulative) > selected:
#
# c:\Users\kevin\anaconda3\lib\codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %% [markdown]
# <a name="Security"></a>
# ## Security with MongoDB.
# For the moment we only worked on MongoDB on localhost, but in a company you'll probably connect to a distant MongoDB.
# If you want to have a server accesible from distance you need to understand some security protocol.
#
# - Bindip: The IP address that mongos or mongod binds to in order to listen for connections from applications. You may attach mongos or mongod to any interface. When attaching mongos or mongod to a publicly accessible interface, ensure that you have implemented proper authentication and firewall restrictions to protect the integrity of your database. 127.0.0.1 is the default bindip = localhost. 0.0.0.0 every ip adress on your network becomes the hostname.
#
# - You need a security protocol to avoid random people connecting to your DB: Setup an authenticate protocol and disallow entrant connection in your firewall (except a whitelist of ip adress you'll use to connect to the host).
#
# To create an authentification protocol start by creating an admin user. Start up your server and open a mongo shell (just type mongo in a terminal)
#
# ```
# mongo
# use admin
#
# db.createUser(
#       {
#           user: "tutorial_2",
#           pwd: passwordPrompt(),
#           roles: [ "root" ]
#       }
#   )
# ```
#
# Now restart your MongoDB server but with the argument --auth in the cmd line.

# %%
# New line if you run with an auth
import pymongo

client = pymongo.MongoClient('mongodb://tutorial:tutorial@localhost:27017')

# %% [markdown]
# If you are interested in connecting to your server from an other ip address please read the following [documentation](https://docs.mongodb.com/manual/tutorial/configure-windows-netsh-firewall/). But be wary, you are entering a new world. If you open your company connection and something goes wrong, you will be held responsible and could get fired. Only use it if you are sure you understand what is going on. (Using mongodb in the university and opening its connection to everyone might results to you being banned from the wifi access for example because it causes a security breach)

# %% [markdown]
# Chances are if you go into a company you won't have to setup all this, all you will have to do is use the username, password and hostip they give you. Most of the time companies uses something called MongoDB Atlas.

# %% [markdown]
# <a name="Atlas"></a>
# ## MongoDB Atlas
#
# Why MongoDB Atlas ?
#
# - Automated Security Features, you don't have to bother with Ip stuff, MongoDB Atlas do it for you.
# - Built-In Replication. If one of their server is down you can still access your DB.
# - Backups and Point-In-Time Recovery - helps you go back in time (sort of like a versioning type of thing), if you mess up (corrupt your DB) than you can use a previous version of your DB.
# - Fine-Grained Monitoring — Tons of info/graph.
# - Automated Patching and One-Click Upgrades
#
# Read more on https://medium.com/@nparsons08/mongodb-atlas-technical-overview-benefits-9e4cff27a75e
#
# MongoDB Atlas has a free small sandbox cluster designed to test and train yourself on clusters.
#
# Let's get started !
#
# https://www.mongodb.com/cloud/atlas/lp/try2?utm_source=google&utm_campaign=gs_emea_france_search_brand_atlas_desktop&utm_term=mongodb%20atlas&utm_medium=cpc_paid_search&utm_ad=e&utm_ad_campaign_id=1718986507&gclid=Cj0KCQjwoJX8BRCZARIsAEWBFMLxFgZxasM-cyNmMhJjE7pPUpbEObrCW1RPC8lcrNfuTRFVMpXRAGcaAmWxEALw_wcB
#
# If you have any trouble or missed a part during lecture please read more on:
# https://university.mongodb.com/mercury/M001/2020_October_6/chapter/Chapter_1_What_is_MongoDB_/lesson/5f32deb504e9ffc01ac9586c/problem
#
# Now let's interact with MongoDB Atlas using pymongo

# %%
# You need to install the next package to use URI from mongo atlas.
# !python -m pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\kevin\anaconda3\lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\kevin\anaconda3\lib\site-packages (from pymongo[srv]) (2.3.0)

# %%
import pymongo

# pymongo.MongoClient can be found on mongodbatlas, you can check the image folder if lost
client = pymongo.MongoClient('mongodb+srv://test:tutorial.@example.ytktu.mongodb.net/sample_airbnb?retryWrites=true&w=majority')
mydb = client["sample_airbnb"]
collection = mydb["listingsAndReviews"]

docs = collection.find()
next(docs)

# %% [markdown]
# Every object that can be transformed to a numpy array(tensor) can be stocked in a MongoDB.

# %% [markdown]
# <a name="control"></a>
# ## Control flow.

# %%
client = pymongo.MongoClient('localhost',27017)
mydb = client["tutorial"]
collection = mydb["benchmark"]

docs = collection.find({"user_id":{"$exists":1,"$gt":10000}}).limit(2) #1 permet de trouver tous les documents ou user_id existe.
list(docs) 

#0 aurait permis de trouver tous les documents où user_id n'existe pas.
#$gt = greater than
#limit(2) : limite le nombre de résultats à 2
#skip(10) : passe les 10 premiers résultats

#Dans Compas : user_id sort(-1) (! syntaxe pas correcte) -> affiche le dernier document ajouté
# Out:
# [{'_id': ObjectId('62417a1d98ccd68530244684'),
#   'user_id': 10001,
#   'user_name': 'John'},
#  {'_id': ObjectId('62417a1d98ccd68530244685'),
#   'user_id': 10002,
#   'user_name': 'John'}]

# %% [markdown]
# <a name="Exercises"></a>
# ### Exercises
#
# #### CRUD operations
#
# Create a new db name Todo and a new collection named "CRUD_exercise" and do the following:

# %%
import pymongo

# open connection at port 27017
client = pymongo.MongoClient('localhost', 27017)
# create db tutorial
mydb = client["todo"]
# create collection example
collection = mydb["crud_exercise"]

# %% [markdown]
# **TODO 1**: Take the dict created in the TODO 4 in chapter II and save it in the collection "CRUD_exercise".

# %%
import tqdm
import json

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["crud_exercise"]

with open('data/Chap2/todo_4.json', 'r') as f:
    chap2_todo4 = json.load(f)

collection.insert_one(chap2_todo4)

# %% [markdown]
# **TODO 2**: Insert 3 documents with key = x and values = 1, delete one of them. Which one is deleted first ? the most recent or oldest one ? increment the value of x to 4.

# %%
client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["crud_exercise"]

for i in tqdm.tqdm(range(3)):
    post = {"x": 1,
            "y": i}
    collection.insert_one(post)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 429.67it/s]

# %%
# get all docs where "x": 1 
docs = collection.find({"x": 1}) #doc est un curseur (générateur)
print(docs)
for doc in docs:
    print(doc)
# Out:
# <pymongo.cursor.Cursor object at 0x000002079133F610>
# {'_id': ObjectId('642d345427881020961be2cf'), 'x': 1, 'y': 0}
# {'_id': ObjectId('642d345427881020961be2d0'), 'x': 1, 'y': 1}
# {'_id': ObjectId('642d345427881020961be2d1'), 'x': 1, 'y': 2}

# %%
collection.delete_one({'x': 1})

docs = collection.find({"x": 1})
print(docs)
for doc in docs:
    print(doc)

#Reading the objectId, we can figure that the oldest has been deleted.
# Out:
# <pymongo.cursor.Cursor object at 0x0000020791306CD0>
# {'_id': ObjectId('642d345427881020961be2d0'), 'x': 1, 'y': 1}
# {'_id': ObjectId('642d345427881020961be2d1'), 'x': 1, 'y': 2}

# %%
# Update every doc where "x" = 1, increment the value by 3
collection.update_many({'x': 1}, {'$inc': {'x': 3}})

docs = collection.find({"x": 4})
print(docs)
for doc in docs:
    print(doc)
# Out:
# <pymongo.cursor.Cursor object at 0x00000207912ECCA0>
# {'_id': ObjectId('642d345427881020961be2d0'), 'x': 4, 'y': 1}
# {'_id': ObjectId('642d345427881020961be2d1'), 'x': 4, 'y': 2}

# %% [markdown]
# **TODO 3**: Insert the dict created in the TODO 6 Chapter II in the example collection.

# %%
import json

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["example"]

with open('data/Chap2/xml_file2.json', 'r') as f:
    xml_file2 = json.load(f)

collection.insert_one(xml_file2)

# %% [markdown]
# **TODO 4**: Get documents where authors key exist in the collection "CRUD_exercise".

# %%
#Ici, je cherche une clé qui existe pour voir si la commande fonctionne

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["crud_exercise"]

matchs = collection.find({'Deep learning': {'$exists': True}})

for match in matchs:
    print(match)

#Le résultat correspond au document "test" -> la commande fonctionne
# Out:
# {'_id': ObjectId('642d342d27881020961be2cd'), 'Deep learning': {'Yann LeCun': '', 'Y.Bengio': 'Université de Montréal', 'Geoffrey Hinton': ''}, 'Generative Adversarial Networks': {'Ian J. Goodfellow': 'Departement d’informatique et de recherche opérationnelle\nUniversite de Montréal\nMontréal, QC H3C 3J7', 'Jean Pouget-Abadie': 'Ecole Polytechnique', 'Mehdi Mirza': 'Departement d’informatique et de recherche opérationnelle\nUniversite de Montréal\nMontréal, QC H3C 3J7', 'Bing Xu': 'Departement d’informatique et de recherche opérationnelle\nUniversite de Montréal\nMontréal, QC H3C 3J7', 'David Warde-Farley': 'Departement d’informatique et de recherche opérationnelle\nUniversite de Montréal\nMontréal, QC H3C 3J7', 'Sherjil Ozair': 'Indian Institute of Technology Delhi', 'Aaron Courville': 'Departement d’informatique et de recherche opérationnelle\nUniversite de Montréal\nMontréal, QC H3C 3J7', 'Yoshua Bengio': 'CIFAR Senior Fellow'}}

# %%
#Je n'avais pas créé de clé "authors" dans todo_4.json -> il ne devrait pas y avoir de match

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["crud_exercise"]

matchs = collection.find({'authors': {'$exists': True}})

for match in matchs:
    print(match)

#En effet, il n'y a pas de match

# %% [markdown]
# **TODO 5**: Change the documents where x = 4 to x = 1.

# %%
client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["crud_exercise"]

collection.update_many({'x': 4}, {'$set': {'x': 1}})

# %% [markdown]
# **TODO 6**: Find documents where author is not_mike and set author as real_mike.

# %%
client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["example"]

collection.find({'author': 'not_mike'})

collection.update_many({'author': 'not_mike'}, {'$set': {'author': 'real_mike'}})

# %% [markdown]
# **TODO 7**: Delete documents where author is real_mike.

# %%
client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["example"]

collection.delete_one({'author': 'real_mike'})

# %% [markdown]
# #### Managing DB
#
# **TODO 8**: create a collection named "CRUD_exercise_benchmark" with 500k observations, ids increment of 2 (sequence:0,2,4,6,...1M). Give a random np.array with a key named "values" and use the insert_many. Then create an index on the id and benchmark queries before and after indexing. Did the index help ?

# %%
from bson.binary import Binary
import pickle
import numpy as np

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["crud_exercise_benchmark"]

list_of_insertion = []
for i in tqdm.tqdm(range(0,1000000,2)):
    dict = {
        'id': i,
        'values': Binary(pickle.dumps(np.random.uniform(4, 2, 3), protocol=2))
        }
    list_of_insertion.append(dict)
    if i % 15000 == 0:
        collection.insert_many(list_of_insertion)
        list_of_insertion = []

collection.insert_many(list_of_insertion)
# Out:
# 100%|██████████| 500000/500000 [00:21<00:00, 23362.90it/s]

# %%
#Benchmark (query without index)

collection.find({"id": 70000}).explain()['executionStats']

#executionTimeMillis': 521
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 521,
#  'totalKeysExamined': 0,
#  'totalDocsExamined': 500000,
#  'executionStages': {'stage': 'COLLSCAN',
#   'filter': {'id': {'$eq': 70000}},
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 44,
#   'works': 500002,
#   'advanced': 1,
#   'needTime': 500000,
#   'needYield': 0,
#   'saveState': 500,
#   'restoreState': 500,
#   'isEOF': 1,
#   'direction': 'forward',
#   'docsExamined': 500000},
#  'allPlansExecution': []}

# %%
#Create index syntax = list of tuples, tuple = ("name of key which will be indexed", order 1 = ascending)
collection.create_index([("id",1)])
# Out:
# 'id_1'

# %%
#Query with index. Will it be faster?

collection.find({"id": 70000}).explain()['executionStats']

#'executionTimeMillis': 7 -> it is much faster
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 7,
#  'totalKeysExamined': 1,
#  'totalDocsExamined': 1,
#  'executionStages': {'stage': 'FETCH',
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 0,
#   'works': 2,
#   'advanced': 1,
#   'needTime': 0,
#   'needYield': 0,
#   'saveState': 0,
#   'restoreState': 0,
#   'isEOF': 1,
#   'docsExamined': 1,
#   'alreadyHasObj': 0,
#   'inputStage': {'stage': 'IXSCAN',
#    'nReturned': 1,
#    'executionTimeMillisEstimate': 0,
#    'works': 2,
#    'advanced': 1,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'keyPattern': {'id': 1},
#    'indexName': 'id_1',
#    'isMultiKey': False,
#    'multiKeyPaths': {'id': []},
#    'isUnique': False,
#    'isSparse': False,
#    'isPartial': False,
#    'indexVersion': 2,
#    'direction': 'forward',
#    'indexBounds': {'id': ['[70000, 70000]']},
#    'keysExamined': 1,
#    'seeks': 1,
#    'dupsTested': 0,
#    'dupsDropped': 0}},
#  'allPlansExecution': []}

# %% [markdown]
# **TODO 9**: create a random collection in a random db and put the new collection in the tutorial DB

# %%
#Create a random collection (todo_9) in a random DB (todo)

import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_9"]

so_random = {"that's": "so random"}
collection.insert_one(so_random)

# %%
#Put the new collection (todo_9) in the tutorial DB

#From MongoDB shell
#Step-1: run the command: use admin
#Step-2: run the command: db.runCommand({renameCollection:"todo.todo_9",to:"tutorial.todo_9"})

# %% [markdown]
# **TODO 10**: What is the difference between an inner join and an outer join ? Is the query seen during course an inner or outer join ? Play with the query to show all the joins.

# %%
#An inner join only keeps the values that are common to both data frames.
#Click on link below for a complete descripion of left/right/full outer join:
#https://stackoverflow.com/questions/38549/what-is-the-difference-between-inner-join-and-outer-join

#The query seen during this course looks like an inner join.

# %%
import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["tutorial"]
collection = mydb["benchmark"]

pipeline = [{'$lookup': 
                {'from' : 'benchmark_2',
                 'localField' : 'user_id',
                 'foreignField' : 'user_id',
                 'as' : 'cellmodels'}},
            {'$unwind': '$cellmodels'},
            {'$project': 
                {'user_id':1,"user_name":1, 'cellmodels.user_id':1, 'cellmodels.random_value':1}} 
             ]
             
documents = collection.aggregate(pipeline)

print(len(list(documents))) #Why is it not working?

# %% [markdown]
# #### Real world problems
#
# **TODO 11**:  Use the oaipmh and api code get papers after January 2020 and for "econ" categories. Insert them in MongoDB. Import only the first 200. How is it sorted ? How can you define your own sort()? Query papers to get papers after 2021, which have 3 authors and with domain "cs".

# %% [markdown]
# **TODO 12**: Do the same as TODO 8 but with the connection to the cluster. Then check the metrics and take screenshot of opcounters, logical size and connections.

# %% [markdown]
# **TODO 13**: Download a random image and store it in a collection.

# %%
# We are using the PIL library to load the image but you can also use other libraries like opencv
from PIL import Image

# Using matplotlib to show the image
from matplotlib import pyplot
image = Image.open('data/Chap3/puss.jpg')
pyplot.imshow(image)
pyplot.show()

# %%
# Now that the image is loaded we need to convert it to a numpy array
import numpy as np
from bson.binary import Binary
import pickle
import pymongo

# img to np array
data = np.asarray(image)
# Check the shape
print(data.shape)
#init dict
post = {}
# pickle dump the numpy array and then binarize it (reminder MongoDB = Bson = Bytes json)
post['image'] = Binary(pickle.dumps(data, protocol=2)) 

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_13"]
collection.insert_one(post)
# Out:
# (632, 474, 3)

# %%
# Load it back

import pymongo
import pickle
from PIL import Image
from matplotlib import pyplot

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_13"]

docs = collection.find()

# load the binary object
doc =  pickle.loads(next(docs)["image"])
print(doc.shape, type(doc))

# From numpy to img
image = Image.fromarray(doc)

# Show image
pyplot.imshow(image)
pyplot.show()
# Out:
# (632, 474, 3) <class 'numpy.ndarray'>

# %% [markdown]
# **TODO 14**: Try to store a pandas dataframe in mongoDB (array with rownames, array with colnames and matrix with values)

# %%
import pymongo
import pandas as pd

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_14"]

movie_reviews = pd.read_csv('data/Chap3/movie_review.tsv', sep='\t', header=0)

movie_reviews.reset_index(inplace=True)
data_dict = movie_reviews.to_dict("records")

collection.insert_many(data_dict)

# %% [markdown]
# **TODO 15**: Insert the movie_review.tsv data into mongodb. Then query it to find the number of review that are positive and negative review. Fetch the docs which have "unexpected" in their review, how many are they ? Think of a clever way to count the number of words in the review using MongoDB (hint: Transform the review text before the insert in MongoDB) and create a density of number of words per review.

# %%
import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_14"]

positive = collection.find({'Sentiment': {'$gt':0}})
negative = collection.find({'Sentiment': {'$lte':0}}) 
#not sure negative reviews are less than or equal to 0 -> ask more info about data set

print('number of negative reviews:', len(list(negative)))
print('number of positive reviews:', len(list(positive)))
# Out:
# number of negative reviews: 7072
# number of positive reviews: 148988

# %%
import pymongo

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_14"]

unexpected = collection.find({'Phrase': {'$regex': r'\bunexpected\b'}}) #Revoir regex de python

print('number of docs which have "unexpected" in their reviews:', len(list(unexpected)))
# Out:
# number of docs which have "unexpected" in their reviews: 143

# %%
#I think I would transorm the variable Phrase into a list, insert it to MongoDB, then find_one for each Sentenceid (hopefully it will be the first one)

# %% [markdown]
# **TODO 16**: Download a [sound sample](https://freesound.org/browse/). Try to store it in MongoDB

# %%
import pydub 
import numpy as np

def read(f, normalized=False):
    """MP3 to numpy array"""
    a = pydub.AudioSegment.from_mp3(f)
    y = np.array(a.get_array_of_samples())
    if a.channels == 2:
        y = y.reshape((-1, 2))
    if normalized:
        return a.frame_rate, np.float32(y) / 2**15
    else:
        return a.frame_rate, y

sound = read('C:/Users/Jason/Music/Naughty_naughty/MP3/Fat_laugh_short.mp3')
# Out:
# c:\Users\Jason\anaconda3\lib\site-packages\pydub\utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7060\2998635487.py in <module>
#      13         return a.frame_rate, y
#      14
# ---> 15 sound = read('C:/Users/Jason/Music/Naughty_naughty/MP3/Fat_laugh_short.mp3')
#
# ~\AppData\Local\Temp\ipykernel_7060\2998635487.py in read(f, normalized)
#       4 def read(f, normalized=False):
#       5     """MP3 to numpy array"""
# ----> 6     a = pydub.AudioSegment.from_mp3(f)
#       7     y = np.array(a.get_array_of_samples())
#       8     if a.channels == 2:
#
# c:\Users\Jason\anaconda3\lib\site-packages\pydub\audio_segment.py in from_mp3(cls, file, parameters)
#     794     @classmethod
#     795     def from_mp3(cls, file, parameters=None):
# --> 796         return cls.from_file(file, 'mp3', parameters=parameters)
#     797
#     798     @classmethod
#
# c:\Users\Jason\anaconda3\lib\site-packages\pydub\audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726             info = None
#     727         else:
# --> 728             info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729         if info:
#     730             audio_streams = [x for x in info['streams']
#
# c:\Users\Jason\anaconda3\lib\site-packages\pydub\utils.py in mediainfo_json(filepath, read_ahead_limit)
#     272
#     273     command = [prober, '-of', 'json'] + command_args
# --> 274     res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#     275     output, stderr = res.communicate(input=stdin_data)
#     276     output = output.decode("utf-8", 'ignore')
#
# c:\Users\Jason\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     949                             encoding=encoding, errors=errors)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#     953                                 startupinfo, creationflags, shell,
#
# c:\Users\Jason\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1418             # Start the process
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#    1422                                          None, None,
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
from audio2numpy import open_audio
import numpy as np

fp = "data/Chap3/sound2mongo.wav"
signal, sampling_rate = open_audio(fp)

# %%
# Now that the sound is loaded we need to convert it to a numpy array
import numpy as np
from bson.binary import Binary
import pickle
import pymongo

# sound to np array
data = np.asarray(sound)
# Check the shape
print(data.shape)
#init dict
post = {}
# pickle dump the numpy array and then binarize it (reminder MongoDB = Bson = Bytes json)
post['sound'] = Binary(pickle.dumps(data, protocol=2)) 

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_16"]
collection.insert_one(post)

# %%
# Load it back

import pymongo
import pickle
from 
from matplotlib import pyplot

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_16"]

docs = collection.find()

# load the binary object
doc =  pickle.loads(next(docs)["sound"])
print(doc.shape, type(doc))

# From numpy to sound
image = Image.fromarray(doc)

# Play sound
pyplot.imshow(image)
pyplot.show()

# %% [markdown]
# **TODO 17**: Create a collection with 30M observation with a single key : "year" which is a random value between 2000-2020. Get documents with year = 2000. Does using an index helps ?

# %%
import pymongo
import random
import tqdm

client = pymongo.MongoClient('localhost', 27017)
mydb = client["todo"]
collection = mydb["todo_17"]

list_of_insertion = []
for i in tqdm.tqdm(range(30000000)):
    dict = {
        'year': random.randint(2000, 2020)
        }
    list_of_insertion.append(dict)
    if i % 15000 == 0:
        collection.insert_many(list_of_insertion)
        list_of_insertion = []

collection.insert_many(list_of_insertion)
# Out:
# 100%|██████████| 30000000/30000000 [08:22<00:00, 59701.28it/s]

# %%
#Benchmark (query without index)

collection.find({"year": 2000}).explain()['executionStats']

#executionTimeMillis': 19609
# Out:
# {'executionSuccess': True,
#  'nReturned': 1427620,
#  'executionTimeMillis': 19609,
#  'totalKeysExamined': 0,
#  'totalDocsExamined': 30000000,
#  'executionStages': {'stage': 'COLLSCAN',
#   'filter': {'year': {'$eq': 2000}},
#   'nReturned': 1427620,
#   'executionTimeMillisEstimate': 801,
#   'works': 30000002,
#   'advanced': 1427620,
#   'needTime': 28572381,
#   'needYield': 0,
#   'saveState': 30000,
#   'restoreState': 30000,
#   'isEOF': 1,
#   'direction': 'forward',
#   'docsExamined': 30000000},
#  'allPlansExecution': []}

# %%
#Create index syntax = list of tuples, tuple = ("name of key which will be indexed", order 1 = ascending)
collection.create_index([("year", 1)])
# Out:
# 'year_1'

# %%
#Query with index. Will it be faster?

collection.find({"year": 2000}).explain()['executionStats']

#'executionTimeMillis': 2307 -> it is much faster BUT creating the index took 1 minute and 28 seconds...
#So, for a single search, it's quicker to search without index.
# Out:
# {'executionSuccess': True,
#  'nReturned': 1427620,
#  'executionTimeMillis': 2307,
#  'totalKeysExamined': 1427620,
#  'totalDocsExamined': 1427620,
#  'executionStages': {'stage': 'FETCH',
#   'nReturned': 1427620,
#   'executionTimeMillisEstimate': 186,
#   'works': 1427621,
#   'advanced': 1427620,
#   'needTime': 0,
#   'needYield': 0,
#   'saveState': 1427,
#   'restoreState': 1427,
#   'isEOF': 1,
#   'docsExamined': 1427620,
#   'alreadyHasObj': 0,
#   'inputStage': {'stage': 'IXSCAN',
#    'nReturned': 1427620,
#    'executionTimeMillisEstimate': 88,
#    'works': 1427621,
#    'advanced': 1427620,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 1427,
#    'restoreState': 1427,
#    'isEOF': 1,
#    'keyPattern': {'year': 1},
#    'indexName': 'year_1',
#    'isMultiKey': False,
#    'multiKeyPaths': {'year': []},
#    'isUnique': False,
#    'isSparse': False,
#    'isPartial': False,
#    'indexVersion': 2,
#    'direction': 'forward',
#    'indexBounds': {'year': ['[2000, 2000]']},
#    'keysExamined': 1427620,
#    'seeks': 1,
#    'dupsTested': 0,
#    'dupsDropped': 0}},
#  'allPlansExecution': []}

# %% [markdown]
# ## Conclusion
#
# After a short introduction on why we are going to focus on MongoDB (Most popular type and DB in the NoSQL domain) we have seen how to work on MongoDB in local, how to perform CRUD operations but also speeding up queries, using complex queries and how to merge multiple DBs/collections. After a short discussion around security on MongoDB, we then move to the cloud version of MongoDB: MongoDB Atlas which facilitates some features (especially security wise). Finishing this chapter is a way to store everything that can be converted into a numpy array.
#
# In the next chapter we will see briefly introduce and discuss other DBs that are rank 1 for their type of data.

# %% [markdown]
# ### Homework 1
#
# pubmed_cleaned.zip is a file containing a metadatas sample from pubmed articles. Your goal is to **convert the json to a mongo DB** and answer the following questions **USING** mongodb querys:
#
# 1) Create an index, explain your choice of key.
#
# 2) Delete every paper that was published prior 2019
#
# 3) How many paper have a single author ? Two authors ?
#
# 4) What's the last paper inserted in the db ?
#
# 5) Find articles with null meshwords.
#
# 6) Choose a keyword you are interested in (machine learning, computer vision,...). Find the number of articles with the choosen keyword in their meshwords, abstract or title.
#
# 7) What's the number of articles that have atleast one affiliation AND meshwords.
#
# 8) How many articles have a publishing date after 2020 ?
#
# 9) Find articles where there's atleast one affiliation from a choosen country (you decide which one).
#
# 10) Check for any duplicates. (hint: look at the doi or the pmid)
#
# 11) Remove every articles where the abstract starts with an "R".
#
# 12) Return the list of papers (pmid) where there's atleast one affiliation per author
#
# 13) Create 500 random samples of the dataset, compute a statistics that you are interested in and check how it behaves through the different samples
#
# 14) Sandbox exercise: think of a problematic and try to answer it.

# %% [markdown]
# ### Homework 2
#
# authors.zip is a file containing a sample of authors that wrote a paper published on pubmed. Each doc as, at most, 5 keys. "AND_ID" is the disambiguated author id. "pmid_list" is the list of ids that the author published. "more_info" is a list of dict with each dict representing info for a given paper. "oa04_affiliations" is a list of dict with each dict representing affiliation info for a given paper. "oa06_researcher_education" is a list of dict with each dict containing information on the education of the researcher.
#
# Your goal is to **convert the json to a mongo DB** and answer the following questions **USING** mongodb querys:
#
# 1) Create an index, explain your choice of key.
#
# 2) What is the average length of "pmid_list"
#
# 3) How many distinct affiliations are there ?
#
# 4) Find authors with atleast one "COM" AffiliationType
#
# 5) How many authors switched the AffiliationType ?
#
# 6) Find affiliation with the word "China"
#
# 7) Get the pmids of papers published in 2019
#
# 8) Count the number of doc with "oa06_researcher_education" OR "oa04_affiliations" key and with the "oa06_researcher_education" AND "oa04_affiliations" .
#
# 9) What's the average "BeginYear" of "oa06_researcher_education".
#
# 10) Count the distinct country of "oa06_researcher_education"
#
# 11) Does the length of pmid_list and more_info always match ?
#
# 12) Does the length of pmid_list and "oa04_affiliations" always match ?
#
# 13) Sandbox exercise: think of a problematic and try to answer it.

# %%
#Seul 1 homework est attendu : on choisit celui qu'on veut
#La deadline sera autour de la semaine d'exam
